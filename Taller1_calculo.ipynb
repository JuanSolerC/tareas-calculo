# %% [markdown]
# # ACTIVIDAD 1: Funciones matemáticas, exponenciales, logarítmicas y trigonométricas

# %% [markdown]
# *Ejercicios compilados por Weimar Muñoz (2023), tomados de:*
# *“Precálculo” de Stewart, Redlin, & Watson, 2016*

# %% [markdown]
# ## Recursos que usaremos ⬇

# %% [markdown]
# 1. **sympy:**
# - **symbols:** Se usa para definir variables simbólicas. Estas variables pueden ser utilizadas en expresiones matemáticas sin necesidad de asignarles un valor numérico.
#
# - **latex:** Convierte una expresión simbólica de sympy en una cadena de texto en formato LaTeX. Esto es útil para mostrar expresiones matemáticas en Jupyter Notebook con un formato profesional.
#
# - **Eq:** Para definir ecuaciones.
#
# - **solve** Para resolver ecuaciones.
#
# - **sqrt** Calcula raíces cuadradas
#
# - **Interval** Representa intervalos de números reales.
#
# - **S** Representa conjuntos simbólicos, como −∞ y ∞
#
# - **FiniteSet** Representa conjuntos de valores finitos
#
# - **Union** Combina conjuntos e intervalos
#
# - **exp** Representa la función exponencial 𝑒^𝑥
#
# - **ln** Representa el logaritmo natural ln(𝑥)
#
# - **re** Extrae la parte real de un número complejo, en caso de que la solución tenga parte imaginaria
#
# - **log** Calcula logaritmos en cualquier base
#
# 2. **IPython.display:**
# - **display:** Es una función que permite mostrar objetos en Jupyter Notebook de manera interactiva. Puede mostrar texto, imágenes, gráficos, expresiones matemáticas, etc.
#
# - **Math:** Es una clase que toma una cadena de texto en formato LaTeX y la renderiza como una expresión matemática en Jupyter Notebook.
#
# 3. **matplotlib:**
# - **pyplot:** Se usa para graficar la funciones
#
# 4. **Numpy:** Se usa para generar listas de valores numéricos

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 1)
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = 2x + 1 \\
# \Huge f(1), f(-2), f\left(\frac{1}{2}\right), f(a), f(-a), f(a + b)
# \end{align*}

# %%
from sympy import symbols, latex
from IPython.display import display, Math

# Definir la variable y la función
x, a, b = symbols('x a b')
f = 2*x + 1

# Evaluar la función en distintos valores
valores = [1, -2, 1/2, a, -a, a + b]
resultados = {v: f.subs(x, v) for v in valores}

# Mostrar la función original
display(Math(r"f(x) = " + latex(f)))

# Mostrar cada evaluación con formato matemático correcto
for valor, resultado in resultados.items():
    expresion = f"f({latex(valor)}) = {latex(f.subs(x, valor))} = {latex(resultado)}"
    display(Math(expresion))
# Out:
# $\displaystyle f(x) = 2 x + 1$
# $\displaystyle f(1) = 3 = 3$
# $\displaystyle f(-2) = -3 = -3$
# $\displaystyle f(0.5) = 2.0 = 2.0$
# $\displaystyle f(a) = 2 a + 1 = 2 a + 1$
# $\displaystyle f(- a) = 1 - 2 a = 1 - 2 a$
# $\displaystyle f(a + b) = 2 a + 2 b + 1 = 2 a + 2 b + 1$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 2) Evalúe la función definida por tramos en los valores indicados.
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) &= \begin{cases}
# \Huge x^2 & \Huge \textrm{si}\, x < 0 \\
# \Huge x+1 & \Huge \textrm{si}\, x \geq 0
# \end{cases} \\
# \Huge f(-2), f(-1), f(0), f(1), f(2)
# \end{align*}

# %%
# Definir la variable simbólica
x = sp.symbols('x')

# Definir la función por tramos
f = sp.Piecewise((x**2, x < 0), (x + 1, x >= 0))

# Evaluar la función en los puntos dados
valores = [-2, -1, 0, 1, 2]
resultados = {x_val: f.subs(x, x_val) for x_val in valores}

# Mostrar los resultados en formato LaTeX
for x_val, resultado in resultados.items():
    display(Math(f"f({x_val}) = {resultado}"))
# Out:
# $\displaystyle f(-2) = 4$
# $\displaystyle f(-1) = 1$
# $\displaystyle f(0) = 1$
# $\displaystyle f(1) = 2$
# $\displaystyle f(2) = 3$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 3) Encuentre el dominio de la función.
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \frac{1}{x-3}
# \end{align*}

# %%
# Definir el dominio en formato LaTeX
dominio_latex = r"\text{Dominio de } f(x) = (-\infty, 3) \cup (3, \infty)"

# Mostrar el dominio
Math(dominio_latex)
# Out:
# $\displaystyle \text{Dominio de } f(x) = (-\infty, 3) \cup (3, \infty)$

# %% [markdown]
# *Esto significa que x puede tomar cualquier valor real excepto 3 ya que al ser una fracción*
# *no puede ser dividida en 0*

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 4) Encuentre el dominio de la función.
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \frac{x^4}{x^2 + x - 6}
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir el denominador
denominador = x**2 + x - 6

# Encontrar los valores que hacen cero el denominador
restricciones = solve(Eq(denominador, 0), x)

# Crear la expresión en LaTeX para el dominio
dominio_latex = r"D_f = \mathbb{R} \setminus \{" + ", ".join(map(str, restricciones)) + r"\}"

# Mostrar el dominio en formato LaTeX
display(Math(dominio_latex))
# Out:
# $\displaystyle D_f = \mathbb{R} \setminus \{-3, 2\}$

# %% [markdown]
# *El dominio de 𝑓(𝑥) son todos los números reales excepto **x=−3 y 𝑥=2***

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 5) Trace la gráfica de la función haciendo primero una tabla de valores
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = -x^2
# \end{align*}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar la tabla de valores
valores_x = np.linspace(-3, 3, 7)  # 7 valores entre -3 y 3
valores_y = -valores_x**2

tabla = "| x  | f(x) = -x^2 |\n|----|-------------|\n"
for i in range(len(valores_x)):
    tabla += f"| {valores_x[i]:.1f} | {valores_y[i]:.1f} |\n"

display(Markdown(tabla))

# Graficar la función
x_vals = np.linspace(-3, 3, 50)
y_vals = -x_vals**2

plt.figure(figsize=(6, 4))
plt.plot(x_vals, y_vals, label="$f(x) = -x^2$", color='blue')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gráfica de f(x) = -x^2")
plt.show()
# Out:
# | x  | f(x) = -x^2 |
# |----|-------------|
# | -3.0 | -9.0 |
# | -2.0 | -4.0 |
# | -1.0 | -1.0 |
# | 0.0 | -0.0 |
# | 1.0 | -1.0 |
# | 2.0 | -4.0 |
# | 3.0 | -9.0 |

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 6) Trace la gráfica de la función haciendo primero una tabla de valores
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge g(x) = x^3-8
# \end{align*}

# %%
# Generar la tabla de valores
valores_x = np.linspace(-3, 3, 7)  # 7 valores entre -3 y 3
valores_y = valores_x**3 - 8

tabla = "| x  | g(x) = x^3 - 8 |\n|----|-------------|\n"
for i in range(len(valores_x)):
    tabla += f"| {valores_x[i]:.1f} | {valores_y[i]:.1f} |\n"

display(Markdown(tabla))

# Graficar la función
gx_vals = np.linspace(-3, 3, 50)
gy_vals = gx_vals**3 - 8

plt.figure(figsize=(6, 4))
plt.plot(gx_vals, gy_vals, label="$g(x) = x^3 - 8$", color='blue')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.xlabel("x")
plt.ylabel("g(x)")
plt.title("Gráfica de g(x) = x^3 - 8")
plt.show()
# Out:
# | x  | g(x) = x^3 - 8 |
# |----|-------------|
# | -3.0 | -35.0 |
# | -2.0 | -16.0 |
# | -1.0 | -9.0 |
# | 0.0 | -8.0 |
# | 1.0 | -7.0 |
# | 2.0 | 0.0 |
# | 3.0 | 19.0 |

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 7) Trace la gráfica de la función haciendo primero una tabla de valores
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x)=1+\sqrt x
# \end{align*}

# %%
# Generar la tabla de valores
valores_x = np.linspace(0, 9, 7)  # 7 valores entre 0 y 9
valores_y = 1 + np.sqrt(valores_x)

tabla = "| x  | f(x) = 1 + √x |\n|----|-------------|\n"
for i in range(len(valores_x)):
    tabla += f"| {valores_x[i]:.1f} | {valores_y[i]:.1f} |\n"


display(Markdown(tabla))

# Graficar la función
fx_vals = np.linspace(0, 9, 100)
fy_vals = 1 + np.sqrt(fx_vals)

plt.figure(figsize=(6, 4))
plt.plot(fx_vals, fy_vals, label=r"$f(x) = 1 + \sqrt{x}$", color='blue')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title(r"Gráfica de $f(x) = 1 + \sqrt{x}$")
plt.show()
# Out:
# | x  | f(x) = 1 + √x |
# |----|-------------|
# | 0.0 | 1.0 |
# | 1.5 | 2.2 |
# | 3.0 | 2.7 |
# | 4.5 | 3.1 |
# | 6.0 | 3.4 |
# | 7.5 | 3.7 |
# | 9.0 | 4.0 |

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 8) Trace la gráfica de la función haciendo primero una tabla de valores
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge H(x)=∣2x∣
# \end{align*}

# %%
# Generar la tabla de valores
valores_x = np.linspace(-5, 5, 7)  # 7 valores entre -5 y 5
valores_y = np.abs(2 * valores_x)

# Formatear la tabla
tabla = "| x  | H(x) = 2x |\n|----|-------------|\n"
for i in range(len(valores_x)):
    tabla += f"| {valores_x[i]:.1f} | {valores_y[i]:.1f} |\n"

# Mostrar en formato Markdown
display(Markdown(tabla))


# Graficar la función
hx_vals = np.linspace(-5, 5, 50)
hy_vals = np.abs(2 * hx_vals)

plt.figure(figsize=(6, 4))
plt.plot(hx_vals, hy_vals, label=r"$H(x) = |2x|$", color='purple')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.xlabel("x")
plt.ylabel("H(x)")
plt.title(r"Gráfica de $H(x) = |2x|$")
plt.show()
# Out:
# | x  | H(x) = 2x |
# |----|-------------|
# | -5.0 | 10.0 |
# | -3.3 | 6.7 |
# | -1.7 | 3.3 |
# | 0.0 | 0.0 |
# | 1.7 | 3.3 |
# | 3.3 | 6.7 |
# | 5.0 | 10.0 |

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 9) Trace la gráfica de la función definida por tramos.
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) &= \begin{cases}
# \Huge 3 & \Huge \textrm{si}\, x < 2 \\
# \Huge x-1 & \Huge \textrm{si}\, x \geq 2
# \end{cases} \\
# \end{align*}

# %%
# Definir los valores de x en los diferentes tramos
x1 = np.linspace(-2, 1.99, 100)  # Tramo x < 2
y1 = np.full_like(x1, 3)         # f(x) = 3

x2 = np.linspace(2, 5, 100)      # Tramo x ≥ 2
y2 = x2 - 1                      # f(x) = x - 1

# Graficar la función por tramos
plt.figure(figsize=(6, 4))
plt.plot(x1, y1, label=r"$f(x) = 3$ si $x < 2$", color='blue')
plt.plot(x2, y2, label=r"$f(x) = x - 1$ si $x \geq 2$", color='red')

# Agregar punto vacío y lleno en x = 2 para mostrar la discontinuidad
plt.scatter(2, 3, color='blue', edgecolors='black', s=50, label="Punto no incluido", zorder=3)
plt.scatter(2, 2-1, color='red', s=50, label="Punto incluido", zorder=3)

# Configuración del gráfico
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.title("Gráfica de la función definida por tramos")

# Mostrar la gráfica
plt.show()

# %% [markdown]
# - *En una función definida por tramos, **los puntos incluidos y no incluidos indican si un valor específico de 𝑥
# pertenece o no a la función en ese punto***
# - *Punto vacío en **(2,3)** → porque la función **no** toma ese valor en 𝑥=2*
# - *Punto lleno en **(2,1)** → porque la función **sí** toma ese valor en 𝑥=2*

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 10) En estos ejercicios se tiene que Trazar la gráfica de la función, no localizando los puntos sino empezando con la gráfica de una función estándar y aplicando transformaciones
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = x^2-1
# \end{align*}

# %%
# Definir las funciones
def g(x):
    return x**2  # Función estándar

def f(x):
    return x**2 - 1  # Función transformada

# Generar valores de x
x_vals = np.linspace(-3, 3, 100)
g_vals = g(x_vals)
f_vals = f(x_vals)

# Crear la figura y los ejes
plt.figure(figsize=(6, 4))

# Graficar la función estándar g(x) = x^2
plt.plot(x_vals, g_vals, linestyle="dashed", color="gray", label=r"$g(x) = x^2$ (Función base)")

# Graficar la función transformada f(x) = x^2 - 1
plt.plot(x_vals, f_vals, color="blue", label=r"$f(x) = x^2 - 1$ (Transformada)")

# Marcar los puntos clave
plt.scatter([0], [-1], color='red', label="Vértice (0, -1)")
plt.scatter([-1, 1], [0, 0], color='green', label="Cortes con X (-1,0) y (1,0)")

# Agregar ejes
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.grid(True, linestyle="--", linewidth=0.5)

# Etiquetas
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Transformación de $g(x) = x^2$ a $f(x) = x^2 - 1$")
plt.legend()
plt.show()

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 11) En estos ejercicios se tiene que Trazar la gráfica de la función, no localizando los puntos sino empezando con la gráfica de una función estándar y aplicando transformaciones
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \sqrt x+1
# \end{align*}

# %%
# Definir las funciones
def g(x):
    return np.sqrt(x)  # Función base

def f(x):
    return np.sqrt(x) + 1  # Función transformada

# Generar valores de x
x_vals = np.linspace(0, 9, 100)  # Solo valores >= 0 porque sqrt(x) no está definido en negativos
g_vals = g(x_vals)
f_vals = f(x_vals)

# Crear la figura y los ejes
plt.figure(figsize=(6, 4))

# Graficar la función base g(x) = sqrt(x)
plt.plot(x_vals, g_vals, linestyle="dashed", color="gray", label=r"$g(x) = \sqrt{x}$ (Función base)")

# Graficar la función transformada f(x) = sqrt(x) + 1
plt.plot(x_vals, f_vals, color="blue", label=r"$f(x) = \sqrt{x} + 1$ (Transformada)")

# Marcar los puntos clave
plt.scatter([0], [1], color='red', label="Inicio en (0,1)")

# Agregar ejes
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.grid(True, linestyle="--", linewidth=0.5)

# Etiquetas
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title(r"Transformación de $g(x) = \sqrt{x}$ a $f(x) = \sqrt{x} + 1$")
plt.legend()
plt.show()

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 12) En estos ejercicios se tiene que Trazar la gráfica de la función, no localizando los puntos sino empezando con la gráfica de una función estándar y aplicando transformaciones
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = (x-5)^2
# \end{align*}

# %%
# Definir funciones
def g(x):
    return x**2  # Función base x^2

def f(x):
    return (x - 5)**2  # Transformación (x-5)^2

# Generar valores de x
x_vals = np.linspace(-2, 10, 100)
g_vals = g(x_vals)
f_vals = f(x_vals)

# Crear la figura
plt.figure(figsize=(6, 4))

# Graficar la función base g(x) = x^2
plt.plot(x_vals, g_vals, linestyle="dashed", color="gray", label=r"$g(x) = x^2$ (Función base)")

# Graficar la función transformada f(x) = (x - 5)^2
plt.plot(x_vals, f_vals, color="blue", label=r"$f(x) = (x - 5)^2$ (Transformada)")

# Marcar los vértices
plt.scatter([0], [0], color='gray', marker='o', label="Vértice de $g(x)$ en (0,0)")
plt.scatter([5], [0], color='red', marker='o', label="Vértice de $f(x)$ en (5,0)")

# Agregar ejes
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.grid(True, linestyle="--", linewidth=0.5)

# Etiquetas
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title(r"Transformación de $g(x) = x^2$ a $f(x) = (x - 5)^2$")
plt.legend()
plt.show()

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 13) En estos ejercicios se tiene que Trazar la gráfica de la función, no localizando los puntos sino empezando con la gráfica de una función estándar y aplicando transformaciones
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \sqrt{x + 4}
# \end{align*}

# %%
# Definir funciones
def g(x):
    return np.sqrt(x)  # Función base sqrt(x)

def f(x):
    return np.sqrt(x + 4)  # Transformación sqrt(x + 4)

# Generar valores de x (ajustando el dominio para evitar valores negativos dentro de la raíz)
x_vals_g = np.linspace(0, 10, 100)  # Dominio para g(x) = sqrt(x)
x_vals_f = np.linspace(-4, 6, 100)  # Dominio para f(x) = sqrt(x + 4)

g_vals = g(x_vals_g)
f_vals = f(x_vals_f)

# Crear la figura
plt.figure(figsize=(6, 4))

# Graficar la función base g(x) = sqrt(x)
plt.plot(x_vals_g, g_vals, linestyle="dashed", color="gray", label=r"$g(x) = \sqrt{x}$ (Función base)")

# Graficar la función transformada f(x) = sqrt(x + 4)
plt.plot(x_vals_f, f_vals, color="blue", label=r"$f(x) = \sqrt{x + 4}$ (Transformada)")

# Marcar los puntos iniciales de cada función
plt.scatter([0], [0], color='gray', marker='o', label="Inicio de $g(x)$ en (0,0)")
plt.scatter([-4], [0], color='blue', marker='o', label="Inicio de $f(x)$ en (-4,0)")

# Agregar ejes
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.grid(True, linestyle="--", linewidth=0.5)

# Etiquetas
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title(r"Transformación de $g(x) = \sqrt{x}$ a $f(x) = \sqrt{x + 4}$")
plt.legend()
plt.show()

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 14) En estos ejercicios se tiene que Trazar la gráfica de la función, no localizando los puntos sino empezando con la gráfica de una función estándar y aplicando transformaciones
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge y = \frac{1}{4} x^2
# \end{align*}

# %%
# Generar la tabla de valores
valores_x = np.linspace(-6, 6, 7)  # Valores entre -6 y 6
valores_y = (1/4) * valores_x**2

tabla = "| x  | f(x) = (1/4) * x^2 |\n|----|-------------|\n"
for i in range(len(valores_x)):
    tabla += f"| {valores_x[i]:.1f} | {valores_y[i]:.1f} |\n"

display(Markdown(tabla))

# Graficar la función estándar y la transformación
fx_vals = np.linspace(-6, 6, 100)
fy_vals_standard = fx_vals**2  # Función estándar f(x) = x^2
fy_vals_transformed = (1/4) * fx_vals**2  # Función transformada f(x) = (1/4)x^2

plt.figure(figsize=(6, 4))
plt.plot(fx_vals, fy_vals_standard, label=r"$g(x) = x^2$", color='red', linestyle='dashed')
plt.plot(fx_vals, fy_vals_transformed, label=r"$f(x) = \frac{1}{4} x^2$", color='blue')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title(r"Comparación de $g(x) = x^2$ y $f(x) = \frac{1}{4} x^2$")
plt.show()
# Out:
# | x  | f(x) = (1/4) * x^2 |
# |----|-------------|
# | -6.0 | 9.0 |
# | -4.0 | 4.0 |
# | -2.0 | 1.0 |
# | 0.0 | 0.0 |
# | 2.0 | 1.0 |
# | 4.0 | 4.0 |
# | 6.0 | 9.0 |

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 15) En estos ejercicios se tiene que Trazar la gráfica de la función, no localizando los puntos sino empezando con la gráfica de una función estándar y aplicando transformaciones
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge y = (x-3)^2+5
# \end{align*}

# %%
# Generar la tabla de valores
valores_x = np.linspace(-6, 6, 7)  # Valores entre -6 y 6
valores_y = (valores_x - 3)**2 + 5

tabla = "| x  | f(x) = (x-3)^2 + 5 |\n|----|-------------|\n"
for i in range(len(valores_x)):
    tabla += f"| {valores_x[i]:.1f} | {valores_y[i]:.1f} |\n"

display(Markdown(tabla))

# Graficar la función estándar y la transformación
fx_vals = np.linspace(-6, 12, 100)
fy_vals_standard = fx_vals**2  # Función estándar f(x) = x^2
fy_vals_transformed = (fx_vals - 3)**2 + 5  # Función transformada f(x) = (x-3)^2 + 5

# Encontrar los vértices
vertex_standard = (0, 0)
vertex_transformed = (3, 5)

plt.figure(figsize=(6, 4))
plt.plot(fx_vals, fy_vals_standard, label=r"$g(x) = x^2$", color='red', linestyle='dashed')
plt.plot(fx_vals, fy_vals_transformed, label=r"$f(x) = (x-3)^2 + 5$", color='blue')
plt.scatter(*vertex_standard, color='red', marker='o', label="Vértice de $g(x)$")
plt.scatter(*vertex_transformed, color='blue', marker='o', label="Vértice de $f(x)$")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title(r"Comparación de $g(x) = x^2$ y $f(x) = (x-3)^2 + 5$ con vértices")
plt.show()
# Out:
# | x  | f(x) = (x-3)^2 + 5 |
# |----|-------------|
# | -6.0 | 86.0 |
# | -4.0 | 54.0 |
# | -2.0 | 30.0 |
# | 0.0 | 14.0 |
# | 2.0 | 6.0 |
# | 4.0 | 6.0 |
# | 6.0 | 14.0 |

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 16) En estos ejercicios se tiene que Trazar la gráfica de la función, no localizando los puntos sino empezando con la gráfica de una función estándar y aplicando transformaciones
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge y = 3-\frac{1}{2} (x-1)^2
# \end{align*}

# %%
# Generar la tabla de valores
valores_x = np.linspace(-3, 3, 7)  # Valores entre -4 y 6
valores_y = 3 - (1/2) * (valores_x - 1)**2

tabla = "| x  |  f(x) = 3 - (1/2) * (x-1)^2  |\n|----|-------------|\n"
for i in range(len(valores_x)):
    tabla += f"| {valores_x[i]:.1f} | {valores_y[i]:.1f} |\n"

display(Markdown(tabla))

# Graficar la función estándar y la transformación
fx_vals = np.linspace(-3, 3, 100)
fy_vals_standard = fx_vals**2  # Función estándar f(x) = x^2
fy_vals_transformed = 3 - (1/2) * (fx_vals - 1)**2  # Función transformada

# Encontrar los vértices
vertex_standard = (0, 0)
vertex_transformed = (1, 3)

plt.figure(figsize=(6, 4))
plt.plot(fx_vals, fy_vals_standard, label=r"$g(x) = x^2$", color='red', linestyle='dashed')
plt.plot(fx_vals, fy_vals_transformed, label=r"$f(x) = 3 - \frac{1}{2} (x-1)^2$", color='blue')
plt.scatter(*vertex_standard, color='red', marker='o', label="Vértice de $g(x)$")
plt.scatter(*vertex_transformed, color='blue', marker='o', label="Vértice de $f(x)$")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title(r"Comparación de $g(x) = x^2$ y $f(x) = 3 - \frac{1}{2} (x-1)^2$ con vértices")
plt.show()
# Out:
# | x  |  f(x) = 3 - (1/2) * (x-1)^2  |
# |----|-------------|
# | -3.0 | -5.0 |
# | -2.0 | -1.5 |
# | -1.0 | 1.0 |
# | 0.0 | 2.5 |
# | 1.0 | 3.0 |
# | 2.0 | 2.5 |
# | 3.0 | 1.0 |

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 17) RESOLVER: encontrar las funciones f+g, f−g, fg, f/g y determinar sus dominios.
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \sqrt{9 - x^2},  g(x) = \sqrt{x^2 -4}
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir las funciones f(x) y g(x)
f = sqrt(9 - x**2)
g = sqrt(x**2 - 4)

# Operaciones con funciones
f_plus_g = f + g
f_minus_g = f - g
f_times_g = f * g
f_div_g = f / g

# Mostrar las operaciones en LaTeX
display(Math(r"f + g = \sqrt{9 - x^2} + \sqrt{x^2 - 4}"))
display(Math(r"f - g = \sqrt{9 - x^2} - \sqrt{x^2 - 4}"))
display(Math(r"f \cdot g = \sqrt{(9 - x^2)(x^2 - 4)}"))
display(Math(r"\frac{f}{g} = " + f"{latex(f_div_g)}"))

# Determinar el dominio de f(x) y g(x)
dom_f = Interval(-3, 3)  # -3 ≤ x ≤ 3
dom_g = Interval(-S.Infinity, -2, True) | Interval(2, S.Infinity, True)  # (-∞, -2] U [2, ∞)

# Intersección de los dominios para f+g, f-g, f·g
dom_common = dom_f.intersect(dom_g)  # [-3,-2] U [2,3]

# Para f/g, quitamos los valores x = ±2 donde g(x) = 0
dom_f_div_g = dom_common - FiniteSet(-2, 2)  # [-3,-2) U (2,3]

# Mostrar los dominios en LaTeX
display(Math(r"\text{Dominio de } f + g \text{ y } f - g: " + f"{latex(dom_common)}"))
display(Math(r"\text{Dominio de } f \cdot g: " + f"{latex(dom_common)}"))
display(Math(r"\text{Dominio de } \frac{f}{g}: " + f"{latex(dom_f_div_g)}"))
# Out:
# $\displaystyle f + g = \sqrt{9 - x^2} + \sqrt{x^2 - 4}$
# $\displaystyle f - g = \sqrt{9 - x^2} - \sqrt{x^2 - 4}$
# $\displaystyle f \cdot g = \sqrt{(9 - x^2)(x^2 - 4)}$
# $\displaystyle \frac{f}{g} = \frac{\sqrt{9 - x^{2}}}{\sqrt{x^{2} - 4}}$
# $\displaystyle \text{Dominio de } f + g \text{ y } f - g: \left[-3, -2\right] \cup \left(2, 3\right]$
# $\displaystyle \text{Dominio de } f \cdot g: \left[-3, -2\right] \cup \left(2, 3\right]$
# $\displaystyle \text{Dominio de } \frac{f}{g}: \left[-3, -2\right) \cup \left(2, 3\right]$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 18) RESOLVER: encontrar las funciones f+g, f−g, fg, f/g y determinar sus dominios.
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \frac{2}{x}, g(x) = \frac{4}{x+4}
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir las funciones
f = 2/x
g = 4/(x+4)

# Operaciones
f_plus_g = f + g
f_minus_g = f - g
f_times_g = f * g
f_div_g = f / g

# Mostrar resultados en LaTeX manualmente
display(Math(r"f + g = \frac{2}{x} + \frac{4}{x+4}"))
display(Math(r"f - g = \frac{2}{x} - \frac{4}{x+4}"))
display(Math(r"f \cdot g = \frac{2}{x} \cdot \frac{4}{x+4} = " + latex(f_times_g)))
display(Math(r"\frac{f}{g} = \frac{\frac{2}{x}}{\frac{4}{x+4}} = \frac{x+4}{2x}"))

# Mostrar dominio
display(Math(r"\text{Dominio: } \mathbb{R} - \{0, -4\}"))
# Out:
# $\displaystyle f + g = \frac{2}{x} + \frac{4}{x+4}$
# $\displaystyle f - g = \frac{2}{x} - \frac{4}{x+4}$
# $\displaystyle f \cdot g = \frac{2}{x} \cdot \frac{4}{x+4} = \frac{8}{x \left(x + 4\right)}$
# $\displaystyle \frac{f}{g} = \frac{\frac{2}{x}}{\frac{4}{x+4}} = \frac{x+4}{2x}$
# $\displaystyle \text{Dominio: } \mathbb{R} - \{0, -4\}$

# %% [markdown]
# ***Esto significa que todas las operaciones tienen el mismo dominio porque:***
# - **Suma y resta no agregan restricciones adicionales.**
# - **Multiplicación tampoco agrega nuevas restricciones.**
# - **División solo requeriría excluir valores donde 𝑔(𝑥)=0, pero como g(x)= 4/x+4, se anula en 𝑥=−4 que ya estaba excluido**

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 19) Encuentre las funciones f∘g, g∘f, f∘f y g∘g y sus dominios
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = 2x+3,  g(x) = 4x-1
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir las funciones f(x) y g(x)
def f(x):
    return 2*x + 3

def g(x):
    return 4*x - 1

# Composiciones de funciones
f_o_g = simplify(f(g(x)))  # f(g(x))
g_o_f = simplify(g(f(x)))  # g(f(x))
f_o_f = simplify(f(f(x)))  # f(f(x))
g_o_g = simplify(g(g(x)))  # g(g(x))

# Imprimir resultados
display(Math(r"f \circ g = " + f"{f_o_g}"))
display(Math(r"g \circ f = " + f"{g_o_f}"))
display(Math(r"f \circ f = " + f"{f_o_f}"))
display(Math(r"g \circ g = " + f"{g_o_g}"))

display(Math(r"\text{Dominio de todas las funciones: } \mathbb{R}"))
# Out:
# $\displaystyle f \circ g = 8*x + 1$
# $\displaystyle g \circ f = 8*x + 11$
# $\displaystyle f \circ f = 4*x + 9$
# $\displaystyle g \circ g = 16*x - 5$
# $\displaystyle \text{Dominio de todas las funciones: } \mathbb{R}$

# %% [markdown]
# *Tanto **𝑓(𝑥)= 2𝑥+3** como **𝑔(𝑥)= 4𝑥−1** son funciones lineales.
# Las funciones lineales están definidas para **todos los números reales***

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 20) Encuentre las funciones f∘g, g∘f, f∘f y g∘g y sus dominios
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = 6x-5,  g(x) = \frac{x}{2}
# \end{align*}

# %%
# Definir la variable simbólica
x = sp.symbols('x')

# Definir las funciones f(x) y g(x)
f = sp.Lambda(x, 6*x - 5)
g = sp.Lambda(x, x / 2)

# Composiciones de funciones
f_o_g = sp.simplify(f(g(x)))  # f(g(x))
g_o_f = sp.simplify(g(f(x)))  # g(f(x))
f_o_f = sp.simplify(f(f(x)))  # f(f(x))
g_o_g = sp.simplify(g(g(x)))  # g(g(x))

# Imprimir resultados
display(Math(r"f \circ g = " + sp.latex(f_o_g)))
display(Math(r"g \circ f = " + sp.latex(g_o_f)))
display(Math(r"f \circ f = " + sp.latex(f_o_f)))
display(Math(r"g \circ g = " + sp.latex(g_o_g)))

# Dominio de todas las funciones
display(Math(r"\text{Dominio de todas las funciones: } \mathbb{R}"))
# Out:
# $\displaystyle f \circ g = 3 x - 5$
# $\displaystyle g \circ f = 3 x - \frac{5}{2}$
# $\displaystyle f \circ f = 36 x - 35$
# $\displaystyle g \circ g = \frac{x}{4}$
# $\displaystyle \text{Dominio de todas las funciones: } \mathbb{R}$

# %% [markdown]
# *Tanto **𝑓(𝑥)= 6x-5** como **𝑔(𝑥)= x/2** son funciones lineales.
# Las funciones lineales están definidas para **todos los números reales***

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 21) Encuentre las funciones f∘g, g∘f, f∘f y g∘g y sus dominios
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = x^2,  g(x) = x+1
# \end{align*}

# %%
# Definir la variable simbólica
x = sp.symbols('x')

# Definir las funciones f(x) y g(x)
f = sp.Lambda(x, x**2)
g = sp.Lambda(x, x + 1)

# Composiciones de funciones
f_o_g = sp.simplify(f(g(x)))  # f(g(x))
g_o_f = sp.simplify(g(f(x)))  # g(f(x))
f_o_f = sp.simplify(f(f(x)))  # f(f(x))
g_o_g = sp.simplify(g(g(x)))  # g(g(x))

# Imprimir resultados
display(Math(r"f \circ g = " + sp.latex(f_o_g)))
display(Math(r"g \circ f = " + sp.latex(g_o_f)))
display(Math(r"f \circ f = " + sp.latex(f_o_f)))
display(Math(r"g \circ g = " + sp.latex(g_o_g)))

# Dominio de todas las funciones
display(Math(r"\text{Dominio de todas las funciones: } \mathbb{R}"))
# Out:
# $\displaystyle f \circ g = \left(x + 1\right)^{2}$
# $\displaystyle g \circ f = x^{2} + 1$
# $\displaystyle f \circ f = x^{4}$
# $\displaystyle g \circ g = x + 2$
# $\displaystyle \text{Dominio de todas las funciones: } \mathbb{R}$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 22) Encuentre las funciones f∘g, g∘f, f∘f y g∘g y sus dominios
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = x^3+2,  g(x) = \sqrt[3]{x}
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir las funciones f(x) y g(x)
def f(x):
    return x**3 + 2

def g(x):
    return x**(1/3)

# Composiciones de funciones
f_o_g = simplify(f(g(x)))  # f(g(x))
g_o_f = simplify(g(f(x)))  # g(f(x))
f_o_f = simplify(f(f(x)))  # f(f(x))
g_o_g = simplify(g(g(x)))  # g(g(x))

# Imprimir resultados en formato LaTeX
display(Math(r"f \circ g = " + latex(f_o_g)))
display(Math(r"g \circ f = " + latex(g_o_f)))
display(Math(r"f \circ f = " + latex(f_o_f)))
display(Math(r"g \circ g = " + latex(g_o_g)))

display(Math(r"\text{Dominio de todas las funciones: } \mathbb{R}"))
# Out:
# $\displaystyle f \circ g = x^{1.0} + 2$
# $\displaystyle g \circ f = \left(x^{3} + 2\right)^{0.333333333333333}$
# $\displaystyle f \circ f = \left(x^{3} + 2\right)^{3} + 2$
# $\displaystyle g \circ g = x^{0.111111111111111}$
# $\displaystyle \text{Dominio de todas las funciones: } \mathbb{R}$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 23) Encuentre las funciones f∘g, g∘f, f∘f y g∘g y sus dominios
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \frac{1}{x},  g(x) = 2x+4
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir las funciones f(x) y g(x)
def f(x):
    return 1/x

def g(x):
    return 2*x + 4

# Composiciones de funciones
f_o_g = simplify(f(g(x)))  # f(g(x))
g_o_f = simplify(g(f(x)))  # g(f(x))
f_o_f = simplify(f(f(x)))  # f(f(x))
g_o_g = simplify(g(g(x)))  # g(g(x))

# Imprimir resultados en formato LaTeX
display(Math(r"f \circ g = " + latex(f_o_g)))
display(Math(r"g \circ f = " + latex(g_o_f)))
display(Math(r"f \circ f = " + latex(f_o_f)))
display(Math(r"g \circ g = " + latex(g_o_g)))

# Dominio de f o g: g(x) != 0
dom_f_o_g = S.Reals - FiniteSet(-2)  # g(x) = 2x + 4 != 0 implica x != -2

# Dominio de g o f: f(x) debe estar definido
dom_g_o_f = S.Reals - FiniteSet(0)  # f(x) no está definido en x = 0

# Dominio de f o f: f(x) y f(f(x)) deben estar definidos
dom_f_o_f = S.Reals - FiniteSet(0)  # f(x) no está definido en x = 0

# Dominio de g o g: g(x) está definido para todo x
dom_g_o_g = S.Reals

# Mostrar dominios
display(Math(r"\text{Dominio de } f \circ g: " + latex(dom_f_o_g)))
display(Math(r"\text{Dominio de } g \circ f: " + latex(dom_g_o_f)))
display(Math(r"\text{Dominio de } f \circ f: " + latex(dom_f_o_f)))
display(Math(r"\text{Dominio de } g \circ g: " + latex(dom_g_o_g)))
# Out:
# $\displaystyle f \circ g = \frac{1}{2 \left(x + 2\right)}$
# $\displaystyle g \circ f = 4 + \frac{2}{x}$
# $\displaystyle f \circ f = x$
# $\displaystyle g \circ g = 4 x + 12$
# $\displaystyle \text{Dominio de } f \circ g: \left(-\infty, -2\right) \cup \left(-2, \infty\right)$
# $\displaystyle \text{Dominio de } g \circ f: \left(-\infty, 0\right) \cup \left(0, \infty\right)$
# $\displaystyle \text{Dominio de } f \circ f: \left(-\infty, 0\right) \cup \left(0, \infty\right)$
# $\displaystyle \text{Dominio de } g \circ g: \mathbb{R}$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 24) Encuentre las funciones f∘g, g∘f, f∘f y g∘g y sus dominios
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = x^2,  g(x) = \sqrt{x -3}
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir las funciones f(x) y g(x)
def f(x):
    return x**2

def g(x):
    return sqrt(x - 3)

# Composiciones de funciones
f_o_g = simplify(f(g(x)))  # f(g(x))
g_o_f = simplify(g(f(x)))  # g(f(x))
f_o_f = simplify(f(f(x)))  # f(f(x))
g_o_g = simplify(g(g(x)))  # g(g(x))

# Imprimir resultados en formato LaTeX
display(Math(r"f \circ g = " + latex(f_o_g)))
display(Math(r"g \circ f = " + latex(g_o_f)))
display(Math(r"f \circ f = " + latex(f_o_f)))
display(Math(r"g \circ g = " + latex(g_o_g)))

# Dominio de f o g: g(x) debe estar en el dominio de f(x)
dom_f_o_g = Interval(3, S.Infinity)

# Dominio de g o f: f(x) debe estar en el dominio de g(x)
dom_g_o_f = solveset(f(x) >= 3, x, domain=S.Reals)

# Dominio de f o f: f(x) está definido en todo R, por lo que se mantiene igual
dom_f_o_f = S.Reals

# Dominio de g o g: g(x) debe estar en su propio dominio
dom_g_o_g = solveset(g(x) >= 3, x, domain=S.Reals)

# Mostrar dominios
display(Math(r"\text{Dominio de } f \circ g: " + latex(dom_f_o_g)))
display(Math(r"\text{Dominio de } g \circ f: " + latex(dom_g_o_f)))
display(Math(r"\text{Dominio de } f \circ f: " + latex(dom_f_o_f)))
display(Math(r"\text{Dominio de } g \circ g: " + latex(dom_g_o_g)))
# Out:
# $\displaystyle f \circ g = x - 3$
# $\displaystyle g \circ f = \sqrt{x^{2} - 3}$
# $\displaystyle f \circ f = x^{4}$
# $\displaystyle g \circ g = \sqrt{\sqrt{x - 3} - 3}$
# $\displaystyle \text{Dominio de } f \circ g: \left[3, \infty\right)$
# $\displaystyle \text{Dominio de } g \circ f: \left(-\infty, - \sqrt{3}\right] \cup \left[\sqrt{3}, \infty\right)$
# $\displaystyle \text{Dominio de } f \circ f: \mathbb{R}$
# $\displaystyle \text{Dominio de } g \circ g: \left[12, \infty\right)$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 25) Encuentre las funciones f∘g∘h
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = x-1,  g(x) = \sqrt{x}, h(x) = x-1
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir las funciones f(x), g(x) y h(x)
def f(x):
    return x - 1

def g(x):
    return sqrt(x)

def h(x):
    return x - 1

# Composición de funciones
f_o_g_o_h = simplify(f(g(h(x))))  # f(g(h(x)))

# Imprimir resultados en formato LaTeX
display(Math(r"f \circ g \circ h = " + latex(f_o_g_o_h)))
# Out:
# $\displaystyle f \circ g \circ h = \sqrt{x - 1} - 1$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 26) Encuentre las funciones f∘g∘h
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \frac{1}{x}, g(x) = x^3, h(x) = x^2+2
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Definir las funciones f(x), g(x) y h(x)
def f(x):
    return 1 / x

def g(x):
    return x**3

def h(x):
    return x**2 + 2

# Composición de funciones
f_o_g_o_h = simplify(f(g(h(x))))  # f(g(h(x)))

# Imprimir resultados en formato LaTeX
display(Math(r"f \circ g \circ h = " + latex(f_o_g_o_h)))
# Out:
# $\displaystyle f \circ g \circ h = \frac{1}{\left(x^{2} + 2\right)^{3}}$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 27) Encuentre la función inversa de f
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = 2x+1
# \end{align*}

# %%
x, y = symbols('x y')

# Definir la ecuación f(x) = y
f_expr = 2*x + 1

# Resolver para x en términos de y
f_inv = solve(f_expr - y, x)[0]

# Imprimir la función inversa correctamente
display(Math(r"f^{-1}(x) = " + latex(f_inv)))
# Out:
# $\displaystyle f^{-1}(x) = \frac{y}{2} - \frac{1}{2}$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 28) Encuentre la función inversa de f
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = 4-x^2, x >= 0
# \end{align*}

# %%
# Definir la variable simbólica
x, y = symbols('x y')

# Definir la función f(x)
f_expr = 4 - x**2

# Resolver para x en términos de y y seleccionar la solución válida (x >= 0)
f_inv = solve(f_expr - y, x)[1]  # Tomamos la raíz positiva

# Imprimir la función inversa en formato LaTeX
display(Math(r"f^{-1}(x) = " + latex(f_inv)))
# Out:
# $\displaystyle f^{-1}(x) = \sqrt{4 - y}$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 29) Nos dan una función f, (a) Trace la gráfica de f, (b) Use la gráfica de f para trazar la gráfica de f^−1, (c) Encuentre f^−1
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge f(x) = \sqrt{x+1}
# \end{align*}

# %%
# Definir la variable simbólica
x, y = symbols('x y')

# Definir la función f(x)
f_expr = sqrt(x + 1)

# Resolver para x en términos de y (inversa de f)
f_inv_expr = solve(f_expr - y, x)[0]  # Despejamos x

# Mostrar la función inversa en LaTeX
display(Math(r"f^{-1}(x) = " + latex(f_inv_expr)))

# Graficar f(x) y f^(-1)(x)
x_vals = np.linspace(-1, 5, 400)  # Dominio de f(x)
y_vals = np.sqrt(x_vals + 1)  # f(x)

x_inv_vals = np.linspace(0, 5, 400)  # Dominio de f^(-1)(x)
y_inv_vals = x_inv_vals**2 - 1  # f^(-1)(x)

plt.figure(figsize=(8, 6))
plt.plot(x_vals, y_vals, label=r'$f(x) = \sqrt{x+1}$', color='blue')
plt.plot(y_inv_vals, x_inv_vals, label=r'$f^{-1}(x) = x^2 -1$', color='red', linestyle='dashed')


plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.legend()
plt.grid()
plt.title("Gráfica de $f(x)$ y su inversa $f^{-1}(x)$")
plt.show()
# Out:
# $\displaystyle f^{-1}(x) = y^{2} - 1$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 30) Encuentre la solución de la ecuación exponencial, redondeada a cuatro lugares decimales
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge e^{1-4x} = 2
# \end{align*}

# %%
from sympy import exp, N, re

# Definir la variable simbólica (asegurando que sea x real real=True)
x = symbols('x', real=True)

# Definir la ecuación exponencial e^(1 - 4x) = 2
eq = Eq(exp(1 - 4*x), 2)

# Resolver la ecuación para x
sol = solve(eq, x)[0]  # Tomamos la única solución real

# Extrae la parte real de la solución, descartando cualquier componente imaginaria.
sol_real = re(sol)

#  Redondea la solución a 4 decimales.
sol_rounded = N(sol_real, 4)

# Mostrar el resultado en formato matemático
display(Math(r"x \approx " + str(sol_rounded)))
# Out:
# $\displaystyle x \approx 0.07671$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 31) Encuentre la solución de la ecuación exponencial, redondeada a cuatro lugares decimales
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge 4(1+10^{5x})=9
# \end{align*}

# %%
from sympy import  log

# Definir la variable simbólica (asegurando que sea x real real=True)
x = symbols('x', real=True)  

# Definir la ecuación
eq = Eq(4 * (1 + 10**(5*x)), 9)

# Resolver la ecuación
sol = solve(eq, x)[0]

# Evaluar y redondear la solución a 4 decimales
sol_rounded = N(sol, 4)

# Mostrar el resultado
display(Math(r"x \approx " + str(sol_rounded)))
# Out:
# $\displaystyle x \approx 0.01938$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 32) De la ecuación logarítmica despeje x.
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge ln x=10
# \end{align*}

# %%
# Definir la variable simbólica
x = symbols('x')

# Calcular la solución
sol = exp(10)

# Redondear a 4 decimales
sol_rounded = N(sol, 4)

# Mostrar el resultado
display(Math(r"x \approx " + str(sol_rounded)))
# Out:
# $\displaystyle x \approx 2.203e+4$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 33) Trace un triángulo que tenga ángulo agudo θ, y encuentre las otras cinco relaciones trigonométricas de θ
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge senθ = \frac{3}{5}
# \end{align*}

# %%
# Dado
sin_theta = Fraction(3, 5)

# Calculando las otras relaciones trigonométricas
cos_theta = Fraction(math.sqrt(1 - sin_theta**2)).limit_denominator()
tan_theta = Fraction(sin_theta / cos_theta).limit_denominator()
cot_theta = Fraction(1 / tan_theta).limit_denominator()
sec_theta = Fraction(1 / cos_theta).limit_denominator()
csc_theta = Fraction(1 / sin_theta).limit_denominator()

# Calcular el lado adyacente usando el coseno
hipotenusa = 5
adyacente = hipotenusa * cos_theta

# Mostrar los resultados usando LaTeX
display(Math(r'\cos \theta = \frac{%s}{%s}' % (cos_theta.numerator, cos_theta.denominator)))
display(Math(r'\tan \theta = \frac{%s}{%s}' % (tan_theta.numerator, tan_theta.denominator)))
display(Math(r'\cot \theta = \frac{%s}{%s}' % (cot_theta.numerator, cot_theta.denominator)))
display(Math(r'\sec \theta = \frac{%s}{%s}' % (sec_theta.numerator, sec_theta.denominator)))
display(Math(r'\csc \theta = \frac{%s}{%s}' % (csc_theta.numerator, csc_theta.denominator)))

# Graficar el triángulo
plt.figure(figsize=(6, 6))
plt.plot([0, adyacente], [0, 0], color='blue', lw=2, label='Base')  # Base
plt.plot([0, 0], [0, 3], color='green', lw=2, label='Altura')  # Altura
plt.plot([0, adyacente], [3, 0], color='red', lw=2, label='Hipotenusa')   # Hipotenusa

# Etiquetas
plt.text(adyacente / 2, -0.5, f'{adyacente}', fontsize=12, ha='center')
plt.text(-0.5, 1.5, '3', fontsize=12, va='center')
plt.text(adyacente / 2, 2, '5', fontsize=12, ha='center')


# Agregar cuadrícula
plt.grid(True)

plt.xlim(-1, 5)
plt.ylim(-1, 4)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Triángulo con ángulo agudo θ')
plt.legend()
plt.show()
# Out:
# $\displaystyle \cos \theta = \frac{4}{5}$
# $\displaystyle \tan \theta = \frac{3}{4}$
# $\displaystyle \cot \theta = \frac{4}{3}$
# $\displaystyle \sec \theta = \frac{5}{4}$
# $\displaystyle \csc \theta = \frac{5}{3}$

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 34) Trace un triángulo que tenga ángulo agudo θ, y encuentre las otras cinco relaciones trigonométricas de θ
#
# </div>

# %% [markdown]
# \begin{align*}
# \Huge cosθ = \frac{9}{40}
# \end{align*}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir los lados del triángulo
hipotenusa = 40
adyacente = 9
opuesto = np.sqrt(hipotenusa**2 - adyacente**2)  # Calculado con Pitágoras

# Coordenadas de los puntos del triángulo
A = (0, 0)
B = (adyacente, 0)
C = (adyacente, opuesto)

# Graficar el triángulo
fig, ax = plt.subplots()
ax.plot([A[0], B[0]], [A[1], B[1]], 'bo-', label=f'Adyacente ({adyacente})')
ax.plot([B[0], C[0]], [B[1], C[1]], 'go-', label=f'Opuesto ({opuesto:.2f})')
ax.plot([C[0], A[0]], [C[1], A[1]], 'ro-', label=f'Hipotenusa ({hipotenusa})')

# Etiquetas de los puntos
ax.text(A[0]-2, A[1], 'A (0,0)', fontsize=12, color='black')
ax.text(B[0]+1, B[1], f'B ({adyacente},0)', fontsize=12, color='black')
ax.text(C[0]+1, C[1], f'C ({adyacente},{opuesto:.2f})', fontsize=12, color='black')

# Mostrar ángulo θ
angle = np.arccos(adyacente / hipotenusa)  # Ángulo en radianes
arc = np.linspace(0, angle, 50)
x_arc = 2 * np.cos(arc)
y_arc = 2 * np.sin(arc)
ax.plot(x_arc, y_arc, 'purple')
ax.text(2, 1, r'$\theta$', fontsize=14, color='purple')

# Configuración del gráfico
ax.set_xlim(-5, 45)
ax.set_ylim(-5, 45)
ax.set_xlabel("Eje X")
ax.set_ylabel("Eje Y")
ax.set_title("Triángulo Rectángulo con θ")
ax.legend()
ax.grid()

plt.show()

# Mostrar relaciones trigonométricas en formato LaTeX
sin_theta = opuesto / hipotenusa
cos_theta = adyacente / hipotenusa
tan_theta = opuesto / adyacente
csc_theta = hipotenusa / opuesto
sec_theta = hipotenusa / adyacente
cot_theta = adyacente / opuesto

from IPython.display import display, Math

relations = f"""
\\begin{{aligned}}
\\sin(\\theta) &= {sin_theta:.2f} \\
\\cos(\\theta) &= {cos_theta:.2f} \\
\\tan(\\theta) &= {tan_theta:.2f} \\
\\csc(\\theta) &= {csc_theta:.2f} \\
\\sec(\\theta) &= {sec_theta:.2f} \\
\\cot(\\theta) &= {cot_theta:.2f} 
\\end{{aligned}}
"""
display(Math(relations))
# Out:
# $\displaystyle
# \begin{aligned}
# \sin(\theta) &= 0.97 \
# \cos(\theta) &= 0.23 \
# \tan(\theta) &= 4.33 \
# \csc(\theta) &= 1.03 \
# \sec(\theta) &= 4.44 \
# \cot(\theta) &= 0.23
# \end{aligned}
# $

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 35) Resuelva el triángulo rectángulo
#
# </div>

# %%
# Dado
altura = 16  # Cateto vertical

# Calcular el otro cateto y la hipotenusa en un triángulo 45°-45°-90°
base = altura  # En un triángulo isósceles de 45°-45°-90°, los catetos son iguales
hipotenusa = altura * np.sqrt(2)

# Coordenadas de los puntos del triángulo
A = (0, 0)
B = (base, 0)
C = (0, altura)

# Graficar el triángulo 
plt.figure(figsize=(6,6))
plt.plot([A[0], B[0]], [A[1], B[1]], 'r-', linewidth=2, label="Base (Cateto 1)")
plt.plot([B[0], C[0]], [B[1], C[1]], 'g-', linewidth=2, label="Hipotenusa")
plt.plot([C[0], A[0]], [C[1], A[1]], 'b-', linewidth=2, label="Altura (Cateto 2)")

# Etiquetas de los puntos
plt.text(A[0]-1, A[1]-1, 'A (0,0)', fontsize=12, color='red')
plt.text(B[0]+0.5, B[1]-1, f'B ({base:.2f},0)', fontsize=12, color='red')
plt.text(C[0]-2, C[1]+0.5, f'C (0,{altura:.2f})', fontsize=12, color='red')

# Ángulos correctamente ubicados
plt.text(A[0]+0.5, A[1]+0.5, '90°', fontsize=12, color='blue')
plt.text(B[0]-3, B[1]+2, '45°', fontsize=12, color='blue')
plt.text(C[0]+1, C[1]-3, '45°', fontsize=12, color='blue')

# Configuración del gráfico
plt.xlim(-5, base + 5)
plt.ylim(-5, altura + 5)
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.title("Triángulo Rectángulo 45°-45°-90°")
plt.show()

# Imprimir resultados
print(f"Base del triángulo: {base:.2f}")
print(f"Hipotenusa del triángulo: {hipotenusa:.2f}")
print(f"Altura del triángulo: {altura}")
# Out:
# Base del triángulo: 16.00
# Hipotenusa del triángulo: 22.63
# Altura del triángulo: 16

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px; border-radius: 5px;">
#
# #### 36) Resuelva el triángulo rectángulo
#
# </div>

# %%
# Dado
altura = 100  # Cateto vertical
angulo_base = 15  # Ángulo en la base (en grados)
angulo_hipotenusa = 75  # Ángulo opuesto a la base

# Calcular la base y la hipotenusa usando trigonometría
base = altura / np.tan(np.radians(angulo_hipotenusa))
hipotenusa = altura / np.sin(np.radians(angulo_hipotenusa))

# Coordenadas de los puntos del triángulo
A = (0, 0)
B = (base, 0)
C = (0, altura)

# Graficar el triángulo con colores diferentes para cada lado
plt.figure(figsize=(6,6))
plt.plot([A[0], B[0]], [A[1], B[1]], 'r-', linewidth=2, label="Base (Cateto 1)")
plt.plot([B[0], C[0]], [B[1], C[1]], 'g-', linewidth=2, label="Hipotenusa")
plt.plot([C[0], A[0]], [C[1], A[1]], 'b-', linewidth=2, label="Altura (Cateto 2)")

# Etiquetas de los puntos
plt.text(A[0]-5, A[1]-5, 'A (0,0)', fontsize=12, color='red')
plt.text(B[0]+2, B[1]-5, f'B ({base:.2f},0)', fontsize=12, color='red')
plt.text(C[0]-10, C[1]+2, f'C (0,{altura:.2f})', fontsize=12, color='red')

# Ángulos correctamente ubicados
plt.text(A[0]+2, A[1]+2, '90°', fontsize=12, color='blue')
plt.text(B[0]-10, B[1]+2, f'{angulo_base}°', fontsize=12, color='blue')
plt.text(C[0]+2, C[1]-10, f'{angulo_hipotenusa}°', fontsize=12, color='blue')

# Configuración del gráfico
plt.xlim(-10, base + 10)
plt.ylim(-10, altura + 10)
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.title("Triángulo Rectángulo 15°-75°-90°")
plt.show()

# Imprimir resultados
print(f"Base del triángulo: {base:.2f}")
print(f"Hipotenusa del triángulo: {hipotenusa:.2f}")
print(f"Altura del triángulo: {altura}")
# Out:
# Base del triángulo: 26.79
# Hipotenusa del triángulo: 103.53
# Altura del triángulo: 100
